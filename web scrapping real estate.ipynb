# %% [markdown]
# # WEB SRAPPING BY REAL ESTATE WEBSITE
#
# Website: https://www.realtor.ca/

# %% [markdown]
# # Import Libraries

# %%
import requests 
import pandas as pd

# %% [markdown]
# # Getting request from website

# %%
cookies = {
    'visid_incap_2269415': 'bFYJeImHTBii7kQf8zn4AFtYLWMAAAAAQUIPAAAAAABB6pQ6kJEK7H3FVbtOxCBG',
    'nlbi_2269415': 'i9UKVQnjwEXq4nGocQkgyAAAAACCum3rKAMUgzAuOPxhxVNB',
    'incap_ses_305_2269415': 'TD86QsaoknZj7JIkNpQ7BFtYLWMAAAAAlnjg6sIDd3ME5+biTTL20g==',
    'incap_ses_1523_2269415': 'DxjpZ0vD2Uwj+zqCr8giFV1YLWMAAAAAi1zQyyNqJAZqZa5QJjh4Qg==',
    '_gid': 'GA1.2.1501193343.1663916128',
    '_fbp': 'fb.1.1663916130219.499735481',
    'gig_bootstrap_3_mrQiIl6ov44s2X3j6NGWVZ9SDDtplqV7WgdcyEpGYnYxl7ygDWPQHqQqtpSiUfko': 'gigya-pr_ver4',
    'ASP.NET_SessionId': 'u0jrxh4oclggfrrttpfncqn4',
    'visid_incap_2271082': 'PZbHmAEwTEG1zHOE8mCPILxYLWMAAAAAQUIPAAAAAAAF6fd8qd70sPY0BHYY1JPp',
    'nlbi_2271082': 'sN/tdZZ1SXivAW+oIpgetQAAAAC3SvN7f4NVMcvLg4CTn8a9',
    'incap_ses_1523_2271082': 'FTQ8LDfu7hdyhjuCr8giFbxYLWMAAAAAkGNT9LWt1wh23/Tf/oDQVg==',
    '_ga': 'GA1.1.909130141.1663916128',
    'nlbi_2269415_2147483392': 'NIhHPgZrXFVOKe5rcQkgyAAAAACCvbRZU2+SSTL97Um9a6z/',
    'reese84': '3:4VaKM+12Ved3HdgzKL9RAA==:...:neK/GFlRwVx78gdo/mwwUUOVQoJKIeB/OUgvX6eFI2g=',
    '_4c_': '%7B%22_4c_s_%22%3A%22fVPbjtsgEP2VFc8hAV8w5K3aStVKrVRVrfq4IjBO0DrGBRx3u8q%2Fl8k6SfeiRnLMnDlzzNyeyLSDnqy5EKXijWqYknxBHuAxkvUTCc7i60DWRG6MVNLW1IiqpFXTaKpVIWlTCym4aI0tOFmQ36jVcKEKXihRyeOCmGHWeCLGW8haXC15teSMtjGHpD8ZKkuWj0PwdjTpPj0OyJtgcxPtQ3ZYODgD95OzaYcCdSmu6A7cdpfwjqJCdAhIWRZ1NibXWz%2B9DpzRS2BTY%2BAm%2BCkCBt%2Fugt%2FDDWco4XMpyM9TBF43QAshnGi7lIa4Xq2maVo%2B%2BjGNG1gav19lVnQJMwigu%2BTD0ugZy5W9wvQEf9b9dtTbU2HQ9Nst2Ju73BXS6i5Cxr4Gf3C9QUq2bv3Yp4A6d711KPENorPQJ6c7H279fg%2FBGd2dvnTxYH2xk5hT57Mb5XLzF%2FkP8SHYfP704f7H3cdsKqZ4yXjFl8%2FDIXghs38M3avMrzmu8EghJp1gVVSKFVxVK8Ek3euQXO9%2BjUA73QONyaUUD67rgLbaBWwIFjeCSc731xJl7HtwuSLhC6Sdz%2BOYbW0dsk4pWSRbaPXYJTSxnabTMTpjIT4kP5DjPJaiYqyUspEVy1OXch4Sofw7PpfmNKX1v%2BxS1rwp37JnaXpuJPT%2Fia%2Ffxh%2Fcea%2B00Lo2NdBNmxeiMoJRVWwstaLksLFNWRf2vFfYhrxzQpbVLMnl9UbtWbIqlDZGCdrotqCcg6GKWUFZURXa8CIHlOTVLYUS72TZnyWvBb4uuJJ1w3imuSHNvHlSlBSNVC%2B5iCD3kjd51x%2Bmi9TsyA9%2FSUXkeDz%2BBQ%3D%3D%22%7D',
    '_ga_Y07J3B53QP': 'GS1.1.1663916128.1.1.1663917970.60.0.0',
}

headers = {
    'authority': 'api2.realtor.ca',
    'accept': '*/*',
    'accept-language': 'en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7',
    'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'origin': 'https://www.realtor.ca',
    'referer': 'https://www.realtor.ca/',
    'sec-ch-ua': '"Google Chrome";v="105", "Not)A;Brand";v="8", "Chromium";v="105"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
}

data = {
    'ZoomLevel': '9',
    'LatitudeMax': '45.81022',
    'LongitudeMax': '-74.50768',
    'LatitudeMin': '44.68485',
    'LongitudeMin': '-77.09222',
    'Sort': '6-D',
    'PropertyTypeGroupID': '1',
    'PropertySearchTypeId': '1',
    'TransactionTypeId': '2',
    'Currency': 'CAD',
    'RecordsPerPage': '12',
    'ApplicationId': '1',
    'CultureId': '1',
    'Version': '7.0',
    'CurrentPage': '1',
}

response = requests.post('https://api2.realtor.ca/Listing.svc/PropertySearch_Post', cookies=cookies, headers=headers, data=data)

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# # Json Object

# %%
results_j=response.json()
results_j
# Out:
# {'ErrorCode': {'Id': 200,
#   'Description': 'Success - OK',
#   'Status': 'Pins-Via-Cache:false;Sidebar-Items-Via-Cache:0;',
#   'ProductName': 'Realtor API 7 (Git) | 20220825.2 | ace473dbe1b4083a5c2dc509e64b74ed0cf470e8 | Thursday, August 25, 2022 1:53:01 PM',
#   'Version': '1.0.8272.32209'},
#  'Paging': {'RecordsPerPage': 12,
#   'CurrentPage': 1,
#   'TotalRecords': 6128,
#   'MaxRecords': 600,
#   'TotalPages': 50,
#   'RecordsShowing': 600,
#   'Pins': 725},
#  'Results': [{'Id': '24906462',
#    'MlsNumber': '1313495',
# ...

# %% [markdown]
# # Targets
#
# Address
#
# Bedrooms
#
# Bathrooms
#
# Agent Name
#
# Area code
#
# Phone number
#
# Price

# %%
results_j.keys()
# Out:
# dict_keys(['ErrorCode', 'Paging', 'Results', 'Pins', 'GroupingLevel'])

# %%
prop=results_j['Results']
prop
# Out:
# [{'Id': '24906462',
#   'MlsNumber': '1313495',
#   'PublicRemarks': 'Opportunity knocks at 205 Lift Lane This home is move-in ready just for you.  This home has a premium lot. There is enough room for a pool, a  patio, and a play structure. You have the opportunity to make the yard your oasis with a water fountain and gardens the space is there for your creativity.  Great schools, fantastic parks, and recreation centre are close by.  Quality upgrades throughout this 3 bedroom 3 bath home that features: hardwood flooring in the kitchen, living and dining room. The elegant white kitchen with quartz island and countertops, subway tile backsplash, stainless steel appliances, pot lights & bonus walk-in pantry; pot lights and gas fireplace in the living room; tons of natural light coming through windows; King-size primary bedroom with walk-in closet and 3 piece ensuite; convenient 2nd floor laundry; fully finished basement with pot lights. (26219957)',
# ...

# %%
#address
prop[1]['Property']['Address']['AddressText']
# Out:
# '2918 SOUTHMORE EAST DRIVE|Ottawa, Ontario K1V6Y8'

# %%
#bedrooms
prop[1]['Building']['Bedrooms']
# Out:
# '2 + 1'

# %%
#bathrooms
prop[1]['Building']['BathroomTotal']
# Out:
# '3'

# %%
#Agent name
prop[1]['Individual'][0]['Name']
# Out:
# 'Heng Yin'

# %%
#Area code
prop[1]['Individual'][0]['Phones'][0]['AreaCode']
# Out:
# '613'

# %%
#Phone number
prop[1]['Individual'][0]['Phones'][0]['PhoneNumber']
# Out:
# '813-9999'

# %%
# Price
prop[1]['Property']['Price']
# Out:
# '$749,900'

# %% [markdown]
# # Combining all data

# %%
address =[]
bedrooms =[]
bathrooms=[]
agent_name=[]
area_code =[]
phone_number=[]
price=[]

for data in prop:
    #address
    try:
        address.append(data['Property']['Address']['AddressText'])
    except:
        address.append('None')
    #bedrooms
    try:
        bedrooms.append(data['Building']['Bedrooms'])
    except:
        bedrooms.append('None')
        
    try:
        bathrooms.append(data['Building']['BathroomTotal'])
    except:
        bathrooms.append('None')
        
    try:
        agent_name.append(data['Individual'][0]['Name'])
    except:
        agent_name.append('None')
        
    try:
        area_code.append(data['Individual'][0]['Phones'][0]['AreaCode'])
    except:
        area_code.append('None')
        
    try:
        phone_number.append(data['Individual'][0]['Phones'][0]['PhoneNumber'])
    except:
        phone_number.append('None')
        
    try:
        price.append(data['Property']['Price'])
    except:
        price.append('None')

# %%
address
# Out:
# ['205 LIFT LANE|Stittsville, Ontario K2V0M7',
#  '2918 SOUTHMORE EAST DRIVE|Ottawa, Ontario K1V6Y8',
#  '926 SERRANO STREET|Ottawa, Ontario K4A5L4',
#  '48 Rue du Joran|Gatineau (Hull), Quebec J9A0G1',
#  '112 Rue Irma-LeVasseur|Gatineau (Buckingham), Quebec J8L0Y7',
#  '278 Rue Alice|Gatineau (Gatineau), Quebec J8P3M5',
#  '268 PEMBINA PRIVATE|Ottawa, Ontario K4M0G7',
#  '1862 LABONTE STREET|Clarence Creek, Ontario K0A1N0',
#  '208 MEADOWLILLY ROAD|Ottawa, Ontario K1T4H1',
#  '999 HERITAGE DRIVE|Merrickville, Ontario K0G1N0',
#  'Lot 15 FORRESTER WAY|Long Sault, Ontario K0C1P0',
#  'Lot 14 FORRESTER WAY|Long Sault, Ontario K0C1P0']

# %% [markdown]
# # DataFrame

# %%
df= pd.DataFrame({'Address':address,
                  'Bedrooms':bedrooms,
                  'Bathrooms':bathrooms,
                  'Agent_name':agent_name,
                  'Area_code':area_code,
                  'Phone_number':phone_number,
                  'Price':price})

# %%
df
# Out:
#                                               Address Bedrooms Bathrooms  \
# 0           205 LIFT LANE|Stittsville, Ontario K2V0M7    3 + 0         3
# 1    2918 SOUTHMORE EAST DRIVE|Ottawa, Ontario K1V6Y8    2 + 1         3
# 2           926 SERRANO STREET|Ottawa, Ontario K4A5L4    3 + 0         3
# 3      48 Rue du Joran|Gatineau (Hull), Quebec J9A0G1        3         3
# 4   112 Rue Irma-LeVasseur|Gatineau (Buckingham), ...        2         1
# 5    278 Rue Alice|Gatineau (Gatineau), Quebec J8P3M5        5         2
# 6          268 PEMBINA PRIVATE|Ottawa, Ontario K4M0G7    2 + 1         2
# 7   1862 LABONTE STREET|Clarence Creek, Ontario K0...    2 + 0         2
# 8         208 MEADOWLILLY ROAD|Ottawa, Ontario K1T4H1    3 + 0         3
# 9     999 HERITAGE DRIVE|Merrickville, Ontario K0G1N0    4 + 0         3
# 10    Lot 15 FORRESTER WAY|Long Sault, Ontario K0C1P0     None         0
# 11    Lot 14 FORRESTER WAY|Long Sault, Ontario K0C1P0     None         0
#
# ...

# %% [markdown]
# # Getting Data from all pages

# %%
address =[]
bedrooms =[]
bathrooms=[]
agent_name=[]
area_code =[]
phone_number=[]
price=[]


for page in range (1,51):
    cookies = {
    'visid_incap_2269415': 'bFYJeImHTBii7kQf8zn4AFtYLWMAAAAAQUIPAAAAAABB6pQ6kJEK7H3FVbtOxCBG',
    'nlbi_2269415': 'i9UKVQnjwEXq4nGocQkgyAAAAACCum3rKAMUgzAuOPxhxVNB',
    'incap_ses_305_2269415': 'TD86QsaoknZj7JIkNpQ7BFtYLWMAAAAAlnjg6sIDd3ME5+biTTL20g==',
    'incap_ses_1523_2269415': 'DxjpZ0vD2Uwj+zqCr8giFV1YLWMAAAAAi1zQyyNqJAZqZa5QJjh4Qg==',
    '_gid': 'GA1.2.1501193343.1663916128',
    '_fbp': 'fb.1.1663916130219.499735481',
    'gig_bootstrap_3_mrQiIl6ov44s2X3j6NGWVZ9SDDtplqV7WgdcyEpGYnYxl7ygDWPQHqQqtpSiUfko': 'gigya-pr_ver4',
    'ASP.NET_SessionId': 'u0jrxh4oclggfrrttpfncqn4',
    'visid_incap_2271082': 'PZbHmAEwTEG1zHOE8mCPILxYLWMAAAAAQUIPAAAAAAAF6fd8qd70sPY0BHYY1JPp',
    'nlbi_2271082': 'sN/tdZZ1SXivAW+oIpgetQAAAAC3SvN7f4NVMcvLg4CTn8a9',
    'incap_ses_1523_2271082': 'FTQ8LDfu7hdyhjuCr8giFbxYLWMAAAAAkGNT9LWt1wh23/Tf/oDQVg==',
    '_ga': 'GA1.1.909130141.1663916128',
    'nlbi_2269415_2147483392': 'NIhHPgZrXFVOKe5rcQkgyAAAAACCvbRZU2+SSTL97Um9a6z/',
    'reese84': '3:4VaKM+12Ved3HdgzKL9RAA==:...:neK/GFlRwVx78gdo/mwwUUOVQoJKIeB/OUgvX6eFI2g=',
    '_4c_': '%7B%22_4c_s_%22%3A%22fVPbjtsgEP2VFc8hAV8w5K3aStVKrVRVrfq4IjBO0DrGBRx3u8q%2Fl8k6SfeiRnLMnDlzzNyeyLSDnqy5EKXijWqYknxBHuAxkvUTCc7i60DWRG6MVNLW1IiqpFXTaKpVIWlTCym4aI0tOFmQ36jVcKEKXihRyeOCmGHWeCLGW8haXC15teSMtjGHpD8ZKkuWj0PwdjTpPj0OyJtgcxPtQ3ZYODgD95OzaYcCdSmu6A7cdpfwjqJCdAhIWRZ1NibXWz%2B9DpzRS2BTY%2BAm%2BCkCBt%2Fugt%2FDDWco4XMpyM9TBF43QAshnGi7lIa4Xq2maVo%2B%2BjGNG1gav19lVnQJMwigu%2BTD0ugZy5W9wvQEf9b9dtTbU2HQ9Nst2Ju73BXS6i5Cxr4Gf3C9QUq2bv3Yp4A6d711KPENorPQJ6c7H279fg%2FBGd2dvnTxYH2xk5hT57Mb5XLzF%2FkP8SHYfP704f7H3cdsKqZ4yXjFl8%2FDIXghs38M3avMrzmu8EghJp1gVVSKFVxVK8Ek3euQXO9%2BjUA73QONyaUUD67rgLbaBWwIFjeCSc731xJl7HtwuSLhC6Sdz%2BOYbW0dsk4pWSRbaPXYJTSxnabTMTpjIT4kP5DjPJaiYqyUspEVy1OXch4Sofw7PpfmNKX1v%2BxS1rwp37JnaXpuJPT%2Fia%2Ffxh%2Fcea%2B00Lo2NdBNmxeiMoJRVWwstaLksLFNWRf2vFfYhrxzQpbVLMnl9UbtWbIqlDZGCdrotqCcg6GKWUFZURXa8CIHlOTVLYUS72TZnyWvBb4uuJJ1w3imuSHNvHlSlBSNVC%2B5iCD3kjd51x%2Bmi9TsyA9%2FSUXkeDz%2BBQ%3D%3D%22%7D',
    '_ga_Y07J3B53QP': 'GS1.1.1663916128.1.1.1663917970.60.0.0',
    }

    headers = {
    'authority': 'api2.realtor.ca',
    'accept': '*/*',
    'accept-language': 'en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7',
    'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
    
    'origin': 'https://www.realtor.ca',
    'referer': 'https://www.realtor.ca/',
    'sec-ch-ua': '"Google Chrome";v="105", "Not)A;Brand";v="8", "Chromium";v="105"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
    }

    data = {
    'ZoomLevel': '9',
    'LatitudeMax': '45.81022',
    'LongitudeMax': '-74.50768',
    'LatitudeMin': '44.68485',
    'LongitudeMin': '-77.09222',
    'Sort': '6-D',
    'PropertyTypeGroupID': '1',
    'PropertySearchTypeId': '1',
    'TransactionTypeId': '2',
    'Currency': 'CAD',
    'RecordsPerPage': '12',
    'ApplicationId': '1',
    'CultureId': '1',
    'Version': '7.0',
    'CurrentPage': str(page),
    }

    response = requests.post('https://api2.realtor.ca/Listing.svc/PropertySearch_Post', cookies=cookies, headers=headers, data=data)
    results_j=response.json()
    prop=results_j['Results']
    
    for data in prop:
        
        
    
        try:
            address.append(data['Property']['Address']['AddressText'])
        except:
            address.append('None')
       
        try:
            bedrooms.append(data['Building']['Bedrooms'])
        except:
            bedrooms.append('None')
        
        try:
            bathrooms.append(data['Building']['BathroomTotal'])
        except:
            bathrooms.append('None')
        
        try:
            agent_name.append(data['Individual'][0]['Name'])
        except:
            agent_name.append('None')
        
        try:
            area_code.append(data['Individual'][0]['Phones'][0]['AreaCode'])
        except:
            area_code.append('None')
        
        try:
            phone_number.append(data['Individual'][0]['Phones'][0]['PhoneNumber'])
        except:
            phone_number.append('None')
        
        try:
            price.append(data['Property']['Price'])
        except:
            price.append('None')

# %%
df= pd.DataFrame({'Address':address,
                  'Bedrooms':bedrooms,
                  'Bathrooms':bathrooms,
                  'Agent_name':agent_name,
                  'Area_code':area_code,
                  'Phone_number':phone_number,
                  'Price':price})

# %%
df
# Out:
#                                                Address Bedrooms Bathrooms  \
# 0            205 LIFT LANE|Stittsville, Ontario K2V0M7    3 + 0         3
# 1     2918 SOUTHMORE EAST DRIVE|Ottawa, Ontario K1V6Y8    2 + 1         3
# 2            926 SERRANO STREET|Ottawa, Ontario K4A5L4    3 + 0         3
# 3       48 Rue du Joran|Gatineau (Hull), Quebec J9A0G1        3         3
# 4    112 Rue Irma-LeVasseur|Gatineau (Buckingham), ...        2         1
# ..                                                 ...      ...       ...
# 595  14154 ANDERSON ROAD UNIT#14|South Stormont, On...    2 + 0         1
# 596          1595 MAXIME STREET|Ottawa, Ontario K1B3K9    3 + 0         2
# 597           1099 CHAREST WAY|Orleans, Ontario K4A4B1    2 + 2         3
# 598      212 FORESTBROOK STREET|Ottawa, Ontario K2K0A7    3 + 0         3
# 599      6545 SILVER MAPLE LANE|Ottawa, Ontario K4P1E2    3 + 1         2
#
#                 Agent_name Area_code Phone_number     Price
# ...

# %% [markdown]
# # Convert Into Excel

# %%
df.to_excel('real estate data.xlsx', index=False)
